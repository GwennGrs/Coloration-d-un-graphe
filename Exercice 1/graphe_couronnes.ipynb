# %%
## Création d'un graphe couronnes à 2n sommets.
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
def crown_graph(n):
    A = ['a{}'.format(i) for i in range(1, n+1)]
    B = ['b{}'.format(i) for i in range(1, n+1)]
    G = nx.Graph()

    G.add_nodes_from(A)
    G.add_nodes_from(B)

    for i in range(n):
        for j in range(n):
            if i != j:
                G.add_edge(A[i], B[j])
    
    return G

# %%
n = 4  
G = crown_graph(n)  

plt.figure(figsize=(5, 5))
pos = nx.circular_layout(G)
nx.draw(G, pos=pos, with_labels=True, node_color="lightgreen", edge_color="gray", node_size=500)
plt.title("Graphe Couronne")
plt.show()

# %%
# Le nombre chromatique du graphe est 2, car le graphe est biparti.
