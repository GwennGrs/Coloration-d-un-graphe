# %% [markdown]
# # Graphe en étoile
# Un [graphe en étoile](https://fr.wikipedia.org/wiki/Graphe_%C3%A9toile) est composé de n noeuds avec 1 seul qui est relié à tous les autres, il n'y a pas de lien entre les autres noeds. Il y à donc n-1 arretes.
#
# ## Exemple

# %%
import networkx as nx
import matplotlib.pyplot as plt
n = 5
G = nx.star_graph(n)
nx.draw_networkx(G)
plt.show()

# %%
def graph_etoile(n):
    G = nx.Graph()
    G.add_node(0)
    for i in range(1, n):
        G.add_node(i)
        G.add_edge(0, i)
    return G

# %%
A = graph_etoile(9)
nx.draw_networkx(A)
plt.show()

# %% [markdown]
# ## Nombre de couleurs
# On peut alors avoir 2 couleurs : une pour le centre et une pour tous les autres points différent du centre de l'étoile.

# %%
def color_graph_etoile(G):
    n = G.number_of_nodes()
    l = []
    l.append("red")
    for i in range(1,n):
        l.append("blue")
    return l
l = color_graph_etoile(A)
nx.draw_networkx(A,node_color=l)
