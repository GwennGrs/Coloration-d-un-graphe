# %%
#Exercice 1
import matplotlib.pyplot as plt
import networkx as nx
# Génération d’un graphe aléatoire à 10 sommets et 20 arêtes
G = nx.cycle_graph(11)
#Visualisation du graphe
nx.draw_networkx(G)
plt.show()

#2 couleur si n pair et 3 couleurs si n impair
